# %%
''' 
Difference Between Database / Data WareHouse / DataLake

Data Base : 
    - A database is any collection of data organized for storage, accessibility, and retrieval.

Data Warehouse:
    - A data warehouse is a type of database primarily designed that you could do Analysis and Reporting.
    - In Data ware house we periodically archie the data from database to data waerehouse.
    - It's a kind of Historical data.
    - The process of taking data from database and Loading into dat ware house is called ETL.

Data Lake:
    - Within the database and datawarehouse the traditional way data stored is table (Rows and Column).
    - Data lake is place were we can store all kind of data like table, Images, videos,Files ..etc
    
Example for Database : SQL Server,Oracle,MS-Access,Excel Spreed sheet
Example for Datawarehouse : SQl Server
Example for DataLake: Its could Based (AWS,Azure,Google Lab)

# %%
'''

What is 'Azure Continer Registry'
    - Azure Container Registry is a private registry service for building, storing, and managing container images and 
      related artifacts
    - Its is Similar to 'Docker hub'

What is 'Azure Continer Instances'
    - Azure Container Instances is a service that enables a developer to deploy containers on the Microsoft Azure public 
      cloud without having to provision or manage any underlying infrastructure

# %%
'''
DevOps:
    - CI (Build) and CD (Release)

# %%
'''
Azure DevOps:
    - Azure DevOps (formerly known as VSTS) is everything you need to build your software product from beginning to end. 
    - Using Azure DevOps You can manage code using Git, test the application, and deploy code using the best CI/CD system.
    
    - Azure DevOps comprises of 5 services that span the breadth of the development cycle

# %% [markdown]
# ![130.png](attachment:130.png)

# %% [markdown]
# # Scenario 01
# #### Manully Pushing Docker Image from local to 'Azure Container Instances'

# %% [markdown]
# ![CICD01.JPG](attachment:CICD01.JPG)

# %%
# 

Step 1: From Local using docker CLI Create Docker Image and push to the 'Azure Container Registry'

Step 2: Login to Azure Portal
    
Step 3: Create 'Azure Container Instances' by refering docker image of 'Azure Container registry'

# %%
# Get the code from Github to Local

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Create 'Container Registry' on Azure portal
# Get the usename and password for the

# %% [markdown]
# ![Container%20Reg.png](attachment:Container%20Reg.png)

# %%
# Run Blow the commands on powershell

# %% [markdown]
# ![125.png](attachment:125.png)

# %%
# Verify the deployment on the 'Container Registry'

# %% [markdown]
# ![126.png](attachment:126.png)

# %%
## Manully Create 'Container Instances' and link Image(dotnetcoredemo-webapi) and image tag (V1)
# Give the dns name
# Browse the DNS name

# %% [markdown]
# ![127.png](attachment:127.png)

# %% [markdown]
# # Scenario 02

# %% [markdown]
# ![CICD02_.jpg](attachment:CICD02_.jpg)

# %%
'''
CI:
  Step 1: Push your code from local to the Got repository
  Step 2: Create Build pipeline
              Connect to 'git repository' -> create 'docker image' -> post to the 'Azure Container registry'

CD:
  Step 1: Create Release pipeline
              Takes 'Docker Image' from 'Azure Container Registry' ->Create 'Azure Container Instances'

# %%
'''
# Login to Azure Devops portal
# Create Team Project
# Establish connection to Azure Services 
# Create CI Pipelines
    - Connect to 'Github' or'Azure repo'
    - Select Empty Job
    - Add taks
        - Copy Files ()
        - Docker : Build and Push the Docker Image
    - Verfiy on the Container Registry for pubshlished Docker Image
# Create CD Pipilines
    - Click on Release and here we are deploying on the 'Azure Container Instances'
    - Generally Select the 'Add and Artifcat' we refer CI outcome as Build get generate, but here we already registered the
      Docker Image on Contianer instances registry
    - Use Arm Template to Deploy Doker Images in the 'Container registry' to 'Container Instances'

# %% [markdown]
# ![128.png](attachment:128.png)

# %% [markdown]
# # Scenario 03

# %% [markdown]
# ![CICD03.jpg](attachment:CICD03.jpg)

# %%
'''
CI:
  Step 1: Push your code from local to the Got repository
  Step 2: Create Build pipeline
              Connect to 'git repository' -> create 'docker image' -> post to the 'Azure Container registry'

CD:
  Step 1: Create Release pipeline
              Takes 'Docker Image' from 'Azure Container Registry' ->Create 'Azure App Services'

# %% [markdown]
# # Scenario 04

# %% [markdown]
# ![129.JPG](attachment:129.JPG)

# %%
'''
1. A developer changes application source code.
2. Application code including the web.config file is committed to the source code repository in Azure Repos.
3. Continuous integration triggers application build and unit tests using Azure Test Plans.
4. Continuous deployment within Azure Pipelines triggers an automated deployment of application artifacts with 
   environment-specific configuration values.
5. The artifacts are deployed to Azure App Service.
6. Azure Application Insights collects and analyzes health, performance, and usage data.
7. Developers monitor and manage health, performance, and usage information.
8. Backlog information is used to prioritize new features and bug fixes using Azure Boards.
